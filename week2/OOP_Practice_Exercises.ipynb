# %% [markdown]
# # OOP Practice Exercises
#
# This notebook is a **pure practice** companion to `OOP_Concepts_and_Code.ipynb`. It contains **no teaching content** — just hands-on tasks so you can test what you've learned.
#
# ## How to use this notebook
# - Read each task carefully.
# - Write your solution in the empty code cell provided right below it (or add a new cell).
# - Try to solve it **before** checking the Solutions section at the end.
# - If you get stuck, re-open `OOP_Concepts_and_Code.ipynb` and review the relevant section.
#
# Tasks are grouped into three levels:
# - **Level 1 — Basic**: direct practice of a single OOP concept.
# - **Level 2 — Applied**: combine 2–3 OOP concepts together.
# - **Level 3 — ML-oriented Challenge**: realistic, data-flavored mini-tasks that mirror how OOP shows up in real ML code.
#
# ---
# ## Table of Contents
# 1. [Level 1 — Basic](#level1)
# 2. [Level 2 — Applied](#level2)
# 3. [Level 3 — ML-oriented Challenge](#level3)
# 4. [Solutions](#solutions)

# %% [markdown]
# <a id="level1"></a>
# # Level 1 — Basic
#
# ### Task 1: Your First Class
# Create a class `Book` with an `__init__` method that accepts `title` and `author`, and stores them as instance attributes. Create one `Book` object and print both attributes.

# %%
# Your code here
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author
        
book1 = Book("Rich Dad Poor dad","Rana Mazhar")
print(book1.title)
print(book1.author)
# Out:
# Rich Dad Poor dad
# Rana Mazhar

# %% [markdown]
# ### Task 2: A Method That Returns a Value
# Add a method `summary()` to a class `Movie` that has `title` and `year` attributes. `summary()` should return a string like `"Inception (2010)"`. Create an object and print the result of calling `summary()`.

# %%
# Your code here
class Movie:
    def __init__(self, title, year):
        self.title = title
        self.year = year
    
    def summary(self):
        return f"{self.title} ({self.year})"

movie1 = Movie("Inception", 2010)
print(movie1.summary())
# Out:
# Inception (2010)

# %% [markdown]
# ### Task 3: Class Attribute vs Instance Attribute
# Create a class `Car` with a class attribute `wheels = 4` (shared by all cars) and an instance attribute `brand` (unique per car, set in `__init__`). Create two `Car` objects with different brands and print each one's `wheels` and `brand`.

# %%
# Your code here
class Car:
    def __init__(self, brand):
        self.wheels = 4
        self.brand = brand

car1 = Car("Toyota")
car2 = Car("Honda")
print(car1.wheels)
print(car1.brand)
print(car2.wheels)
print(car2.brand)
# Out:
# 4
# Toyota
# 4
# Honda

# %% [markdown]
# ### Task 4: Multiple Objects in a Loop
# Create a class `Employee` with `name` and `salary` attributes. Create a list of at least 3 `Employee` objects. Loop through the list and print each employee's name and salary using an f-string.

# %%
# Your code here
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

records = [
    Employee("Ali", 50000),
    Employee("Sara", 60000),
    Employee("John", 55000)
]

for record in records:
    print(f"Employee: {record.name}, Salary: {record.salary}")
# Out:
# Employee: Ali, Salary: 50000
# Employee: Sara, Salary: 60000
# Employee: John, Salary: 55000

# %% [markdown]
# ### Task 5: `__str__` for Readable Output
# Add a `__str__` method to the `Employee` class from Task 4 so that `print(employee)` shows something like `"Employee: Ali, Salary: 50000"`. Test it on one object.

# %%
# Your code here
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary
    def __str__(self):
        return f"Employee : name={self.name}, salary={self.salary}"

employee1 = Employee("Ali", 50000)
print(employee1)
# Out:
# Employee : name=Ali, salary=50000

# %% [markdown]
# <a id="level2"></a>
# # Level 2 — Applied
#
# ### Task 6: A Method That Uses Other Attributes
# Create a class `Rectangle` with `width` and `height` attributes, and two methods: `area()` (returns `width * height`) and `perimeter()` (returns `2 * (width + height)`). Create an object and print both results.
#
# ### Task 7: Encapsulation with a Guard Condition
# Create a class `Wallet` with a "protected" attribute `_balance` (starting value passed into `__init__`). Add a method `withdraw(amount)` that only allows the withdrawal if `amount <= self._balance`; otherwise it should print `"Insufficient funds."` and not change the balance. Add a method `get_balance()` to check the balance. Test both a successful and a failed withdrawal.
#
# ### Task 8: Basic Inheritance
# Create a parent class `Vehicle` with `brand` and `speed` attributes and a method `describe()` returning a sentence about the vehicle. Create a child class `ElectricVehicle` that inherits from `Vehicle`, adds a `battery_range` attribute, and overrides `describe()` to also mention the battery range (using `super()` to reuse the parent's description).
#
# ### Task 9: A List of Mixed Objects with a Shared Method
# Create two classes, `Circle` (with `radius`) and `Square` (with `side`), each with an `area()` method (`radius ** 2 * 3.1416` and `side ** 2` respectively). Put one of each into a list and loop through it, printing each shape's area — this is polymorphism in action.
#
# ### Task 10: Combine Class + List Comprehension
# Create a class `Product` with `name` and `price` attributes. Create a list of at least 4 `Product` objects with different prices. Using a list comprehension, build a new list containing only the **names** of products priced above `100`.

# %% [markdown]
# *(Write your solutions for Tasks 6–10 in the cells below.)*

# %%
# Task 6 -- Your code here

# %%
# Task 7 -- Your code here

# %%
# Task 8 -- Your code here

# %%
# Task 9 -- Your code here

# %%
# Task 10 -- Your code here

# %% [markdown]
# <a id="level3"></a>
# # Level 3 — ML-oriented Challenge
#
# ### Task 11: A Simple `Dataset` Class
# Create a class `Dataset` that stores a list of numeric values (passed into `__init__`). Add methods:
# - `mean()` — returns the average of the values.
# - `minimum()` — returns the smallest value.
# - `maximum()` — returns the largest value.
# - `normalize()` — returns a **new list** where each value is scaled to the range `[0, 1]` using `(value - minimum) / (maximum - minimum)`.
#
# Test all four methods on `Dataset([10, 20, 30, 40, 50])`.
#
# ### Task 12: A Base `Model` Class and Two Subclasses
# Create a base class `BaseModel` with an `__init__` that sets `self.is_trained = False`, and a method `predict()` that raises a `ValueError` if `self.is_trained` is `False` (mirroring the `SimpleAverageModel` example from the concepts notebook).
#
# Create two child classes:
# - `ConstantModel` — its `fit(training_values)` stores a fixed constant (e.g. the maximum of `training_values`) and sets `self.is_trained = True`; its `predict(n)` returns a list of `n` copies of that constant.
# - `AverageModel` — its `fit(training_values)` stores the average, and `predict(n)` returns `n` copies of the average.
#
# Both should reuse the parent's `predict()` guard logic somehow (hint: you can still call `super().predict()` first inside the child's `predict()`, purely to trigger the "not trained" check, before returning your own result — or re-check `self.is_trained` directly).
#
# Train both models on `[5, 10, 15, 20, 25]`, call `predict(3)` on each, and print the results. Then create a third, **untrained** model of either type and confirm calling `predict()` raises the expected error.
#
# ### Task 13: Records as Objects
# You previously worked with student records as dictionaries: `{"name": "Ali", "marks": [78, 85, 90]}`. Rewrite this idea using a class `StudentRecord` with `name` and `marks` attributes, and methods `average()` and `grade()` (same grading rule as earlier notebooks: `>=90` → `"A"`, `>=75` → `"B"`, `>=60` → `"C"`, else `"F"`). Create a list of at least 4 `StudentRecord` objects, then use a list comprehension to build a list of names of students with grade `"A"` or `"B"`.

# %%
# Task 11 -- Your code here

# %%
# Task 12 -- Your code here

# %%
# Task 13 -- Your code here

# %% [markdown]
# ---
# <a id="solutions"></a>
# # Solutions
#
# Only check these after attempting each task yourself!

# %% [markdown]
# ### Solution 1

# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author

book1 = Book("Deep Work", "Cal Newport")
print(book1.title)
print(book1.author)

# %% [markdown]
# ### Solution 2

# %%
class Movie:
    def __init__(self, title, year):
        self.title = title
        self.year = year

    def summary(self):
        return f"{self.title} ({self.year})"

movie1 = Movie("Inception", 2010)
print(movie1.summary())

# %% [markdown]
# ### Solution 3

# %%
class Car:
    wheels = 4   # class attribute

    def __init__(self, brand):
        self.brand = brand   # instance attribute

car1 = Car("Toyota")
car2 = Car("Honda")

print(car1.brand, car1.wheels)
print(car2.brand, car2.wheels)

# %% [markdown]
# ### Solution 4

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

employees = [
    Employee("Ali", 50000),
    Employee("Sara", 65000),
    Employee("Ahmed", 48000),
]

for emp in employees:
    print(f"{emp.name}: {emp.salary}")

# %% [markdown]
# ### Solution 5

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def __str__(self):
        return f"Employee: {self.name}, Salary: {self.salary}"

employee1 = Employee("Ali", 50000)
print(employee1)

# %% [markdown]
# ### Solution 6

# %%
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

    def perimeter(self):
        return 2 * (self.width + self.height)

rect1 = Rectangle(5, 3)
print(rect1.area())
print(rect1.perimeter())

# %% [markdown]
# ### Solution 7

# %%
class Wallet:
    def __init__(self, balance):
        self._balance = balance

    def withdraw(self, amount):
        if amount <= self._balance:
            self._balance -= amount
            print(f"Withdrew {amount}. New balance: {self._balance}")
        else:
            print("Insufficient funds.")

    def get_balance(self):
        return self._balance

wallet1 = Wallet(1000)
wallet1.withdraw(300)     # succeeds
wallet1.withdraw(5000)    # fails
print(wallet1.get_balance())

# %% [markdown]
# ### Solution 8

# %%
class Vehicle:
    def __init__(self, brand, speed):
        self.brand = brand
        self.speed = speed

    def describe(self):
        return f"{self.brand} can travel at {self.speed} km/h."


class ElectricVehicle(Vehicle):
    def __init__(self, brand, speed, battery_range):
        super().__init__(brand, speed)
        self.battery_range = battery_range

    def describe(self):
        base = super().describe()
        return f"{base} It has a battery range of {self.battery_range} km."


ev = ElectricVehicle("Tesla", 250, 500)
print(ev.describe())

# %% [markdown]
# ### Solution 9

# %%
class Circle:
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return self.radius ** 2 * 3.1416


class Square:
    def __init__(self, side):
        self.side = side

    def area(self):
        return self.side ** 2


shapes = [Circle(5), Square(4)]

for shape in shapes:
    print(f"{type(shape).__name__} area: {shape.area():.2f}")

# %% [markdown]
# ### Solution 10

# %%
class Product:
    def __init__(self, name, price):
        self.name = name
        self.price = price

products = [
    Product("Keyboard", 45),
    Product("Monitor", 150),
    Product("Mouse", 25),
    Product("Laptop", 1200),
]

expensive_names = [p.name for p in products if p.price > 100]
print(expensive_names)

# %% [markdown]
# ### Solution 11

# %%
class Dataset:
    def __init__(self, values):
        self.values = values

    def mean(self):
        return sum(self.values) / len(self.values)

    def minimum(self):
        return min(self.values)

    def maximum(self):
        return max(self.values)

    def normalize(self):
        low = self.minimum()
        high = self.maximum()
        return [(v - low) / (high - low) for v in self.values]


data = Dataset([10, 20, 30, 40, 50])
print("Mean:", data.mean())
print("Min:", data.minimum())
print("Max:", data.maximum())
print("Normalized:", data.normalize())

# %% [markdown]
# ### Solution 12

# %%
class BaseModel:
    def __init__(self):
        self.is_trained = False

    def predict(self):
        if not self.is_trained:
            raise ValueError("Model has not been trained yet. Call fit() first.")


class ConstantModel(BaseModel):
    def __init__(self):
        super().__init__()
        self.constant = None

    def fit(self, training_values):
        self.constant = max(training_values)
        self.is_trained = True

    def predict(self, n):
        super().predict()   # reuse the parent's "not trained" guard
        return [self.constant] * n


class AverageModel(BaseModel):
    def __init__(self):
        super().__init__()
        self.average = None

    def fit(self, training_values):
        self.average = sum(training_values) / len(training_values)
        self.is_trained = True

    def predict(self, n):
        super().predict()
        return [self.average] * n


training_data = [5, 10, 15, 20, 25]

constant_model = ConstantModel()
constant_model.fit(training_data)
print(constant_model.predict(3))

average_model = AverageModel()
average_model.fit(training_data)
print(average_model.predict(3))

untrained_model = AverageModel()
try:
    untrained_model.predict(2)
except ValueError as error:
    print("Error:", error)

# %% [markdown]
# ### Solution 13

# %%
class StudentRecord:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

    def average(self):
        return sum(self.marks) / len(self.marks)

    def grade(self):
        avg = self.average()
        if avg >= 90:
            return "A"
        elif avg >= 75:
            return "B"
        elif avg >= 60:
            return "C"
        else:
            return "F"


students = [
    StudentRecord("Ali", [78, 85, 90]),
    StudentRecord("Sara", [88, 92, 95]),
    StudentRecord("Ahmed", [55, 62, 58]),
    StudentRecord("Ayesha", [90, 87, 93]),
]

top_students = [s.name for s in students if s.grade() in ("A", "B")]
print(top_students)

# %% [markdown]
# ---
# **Well done!** You've now practiced the core OOP concepts you'll need to comfortably read and use ML libraries like Scikit-learn, which rely on classes and objects throughout their API.
